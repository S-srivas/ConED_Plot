# %%
# By Saina Srivastava, Aug 2019

# I'm trying to have the program read a certain aspect of the file so I can plot the corelation 
#between the usage of electricity and the interval of months it was used (bar graph)
import matplotlib.pyplot as plt; plt.rcdefaults()
from pylab import bar, show, plot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Here I am reading the file and telling my program to read the 'Days' aspect of my file.
df = pd.read_csv('data/ConEd Electricity Plot.csv', parse_dates=['Days'], index_col='Days')

# %%
# Here, I am defining my funtion and laying out the backbone of the program
def plot_df(df, x, y, title="", xlabel='Days', ylabel='Usage', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    #plt.bar is used to create bar graphs.
    plt.bar(x, y, color='turquoise')
    #plt.gca is used to tell the axis where they are
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.xticks(rotation=90)
    
    plt.show()

plot_df(df, x=df.index, y=df.Usage, title='Corolation of electricity and date (Month-Wise)')

# %%
# I'm trying to have the program read a certain aspect of the file so I can plot the coralation 
#between the usage of electricity and the interval of days it was used (line graph)
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('data/cned_1day_data.csv', parse_dates=['Start_time'], index_col='Start_time')

# %%
## Here, I am defining my funtion and laying out the backbone of the program
def plot_df(df, x, y, title="", xlabel='Days', ylabel='Usage', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    #plt.plot is used to for graphing lines
    plt.plot(x, y, color='tab:pink')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.xticks(rotation=90)
    plt.show()

plot_df(df, x=df.index, y=df.Value, title='Corolation of electricity and date (Day-wise)')

# %%
# Here I'm trying to create a plot that displays both the usage(bar graph) and cost (line graph)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt
from pylab import bar, show, plot

df=pd.read_csv('data/cned trial.csv', parse_dates=['START DATE'], index_col='START DATE')
df_smallcols = pd.read_csv('data/cned trial.csv',usecols = ['COST'])

# %%
# Just checking the data loaded
df
# Out:
#             USAGE    COST
# START DATE
# 2016-07-15    783  196.84
# 2016-08-23    375   99.82
# 2016-09-22    211   64.31
# 2016-10-21    243   72.48
# 2016-11-22    218   68.42
# 2016-12-22    192   59.46
# 2017-01-25    156   54.61
# 2017-02-24    142   50.43
# 2017-03-25    181   55.92
# 2017-04-22    186   63.22
# 2017-05-23    309   89.11
# 2017-06-22    551  143.81
# 2017-07-22    493  126.11
# 2017-08-22    304   85.29
# 2017-09-21    289   84.23
# 2017-10-20    192   62.03
# 2017-11-21    165   52.58
# 2017-12-21    135   52.29
# 2018-01-24    147   49.54
# 2018-02-23    149   53.10
# 2018-03-24    141   51.88
# 2018-04-24    183   61.12
# 2018-05-23    321   95.64
# 2018-06-22    556  158.26
# 2018-07-24    487  133.20
# 2018-08-22    379  103.34
# 2018-09-21    201   65.84
# 2018-10-20    170   57.34
# 2018-11-21    143   47.94
# 2018-12-21    146   52.33
# 2019-01-24    135   45.80
# 2019-02-23    138   48.87
# 2019-03-26    129   41.82
# 2019-04-24    134   42.47
# ...

# %%
## Here, I put them both in the same funtion so they can be plotted together.
def plot_df_2plots(df, x, y, z, title="", xlabel='START DATE', ylabel='Usage', m1_tlabel='Cost', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.bar(x, y, color='purple')
    plt.plot(x, z, color='red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.xticks(rotation=90)
    plt.show()

plot_df_2plots(df, x=df.index, y=df.USAGE, z=df_smallcols, title='Graph style #2')

# %%
# Here I want to try to make two seperate graphs, one to represent usage(bar graph) and cost(line graph)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt
from pylab import bar, show, plot

df=pd.read_csv('data/cned trial.csv', parse_dates=['START DATE'], index_col='START DATE')
df_smallcols = pd.read_csv('data/cned trial.csv',usecols = ['COST'])

# %%
# This has the same foundation as the ones before. So the entire funtion is about the creation of a bar graph
def plot_df(df, x, y, title="", xlabel='START DATE', ylabel='Usage', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.bar(x, y, color='purple')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.xticks(rotation=90)
    plt.show()
    
plot_df(df, x=df.index, y=df.USAGE, title='Plot way #1')
df_smallcols.plot(secondary_y=True)

# %%
# This is an example of shared axixes graphs
import matplotlib.pyplot as plt
import numpy as np


t = np.arange(0.01, 5.0, 0.01)
s1 = np.sin(2 * np.pi * t)
s2 = np.exp(-t)
s3 = np.sin(4 * np.pi * t)

ax1 = plt.subplot(311)
plt.plot(t, s1)

# share x only
ax2 = plt.subplot(312, sharex=ax1)
plt.plot(t, s2)
# make these tick labels invisible
plt.setp(ax2.get_xticklabels(), visible=False)

# share x and y
ax3 = plt.subplot(313, sharex=ax1, sharey=ax1)
plt.plot(t, s3)
plt.xlim(0.01, 5.0)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt
from pylab import bar, show, plot

df=pd.read_csv('data/cned trial.csv', parse_dates=['START DATE'], index_col='START DATE')
m1_t = pd.read_csv('data/cned trial.csv',usecols = ['COST'])

# %%
def plot_df(df, x, y, title="", xlabel='START DATE', ylabel='Usage', m1_tlabel='Cost', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.bar(x, y, color='purple')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.xticks(rotation=90)
    plt.show()
    file1 = plot_df(df, x=df.index, y=df.USAGE, title='Style 3')
    file2 = m1_t
    plt.subplot(311)
    plt.plot(file1)
    plt.subplot(312, sharex=ho)
    plt.plot(file2)

# %%
# This is an example of labeling a line graph
from matplotlib import pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)

A = -0.75, -0.25, 0, 0.25, 0.5, 0.75, 1.0
B = 0.73, 0.97, 1.0, 0.97, 0.88, 0.73, 0.54

plt.plot(A,B)
for xy in zip(A, B):                                      
    ax.annotate('(%s, %s)' % xy, xy=xy, textcoords='data')
    #plt.grid()
    plt.show()

# %%
# this is an example program for the line and bar graph in one graph thing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

width = .35
m1_t = pd.DataFrame({
 'abnormal' : [90,40,30,30,30,25,25,20,15,10],
 'fix' : [60,70,65,70,70,60,50,45,45,45],
 'normal' : [140,160,170,180,190,200,210,220,230,240],
 'bad_rate' : [210,100,100,70,70,75,70,60,65,60]})

m1_t[['abnormal','fix','normal']].plot(kind='bar', width = width)
m1_t['bad_rate'].plot(secondary_y=True)

ax = plt.gca()
plt.xlim([-width, len(m1_t['normal'])-width])
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10'))

plt.show()
